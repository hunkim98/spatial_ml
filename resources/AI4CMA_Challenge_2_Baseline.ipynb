# %%
# %pip install numpy opencv-python matplotlib requests rasterio
# Out:
# Requirement already satisfied: numpy in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (2.2.6)
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: matplotlib in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: requests in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (2.32.5)
# Collecting rasterio
#   Downloading rasterio-1.4.4-cp310-cp310-macosx_14_0_arm64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 11.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyparsing>=3 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from requests) (2.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from requests) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: attrs in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from rasterio) (25.4.0)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from rasterio) (8.3.1)
# Requirement already satisfied: click-plugins in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from rasterio) (1.1.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: six>=1.5 in /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: opencv-python, cligj, affine, rasterio
# Successfully installed affine-2.4.0 cligj-0.7.2 opencv-python-4.13.0.92 rasterio-1.4.4
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
For Windows Users - Preventing GDAL errors 

1) Go to https://www.lfd.uci.edu/~gohlke/pythonlibs/ and download the appropriate GDAL and rasterio .whl files. 
   The .whl files are named based on the Python version (e.g., cp39 == Python 3.9) and Windows architecture (e.g. amd64 = 64bit)

2) In the command prompt, activate your Python env. and go to the directory where the .whl files have been downloaded. 

3) pip install gdal .whl file first, followed by the rasterio. 

NOTE: 

If you have ArcPy in the same conda/pythonenv environment and intend to import both packages at the same time in a script, 
you must import arcpy first before rasterio. Importing rasterio on its own without the use of ArcPy is fine. 

"""
# Out:
# '\nFor Windows Users - Preventing GDAL errors \n\n1) Go to https://www.lfd.uci.edu/~gohlke/pythonlibs/ and download the appropriate GDAL and rasterio .whl files. \n   The .whl files are named based on the Python version (e.g., cp39 == Python 3.9) and Windows architecture (e.g. amd64 = 64bit)\n\n2) In the command prompt, activate your Python env. and go to the directory where the .whl files have been downloaded. \n\n3) pip install gdal .whl file first, followed by the rasterio. \n\nNOTE: \n\nIf you have ArcPy in the same conda/pythonenv environment and intend to import both packages at the same time in a script, \nyou must import arcpy first before rasterio. Importing rasterio on its own without the use of ArcPy is fine. \n\n'

# %%
import numpy as np
import cv2
import json
import matplotlib.pyplot as plt
import requests
import shutil
import os
import rasterio

# %%
# download inputs:
#     This is just for example. The actual data can be downloaded from the provoded links to the performers!

# Code for downloading image from a url
input_test_data_url='https://raw.githubusercontent.com/nasa-jpl/USGS-DARPA-challange-resources/main/test_data2.zip'
test_data = requests.get(input_test_data_url).content
with open('test_data2.zip', 'wb') as handler:
    handler.write(test_data)
# unzip
shutil.unpack_archive('test_data2.zip', '.', 'zip')

# %%
# create directory to store results
os.makedirs('results', exist_ok=True)

# %%
data_dir='test_data2'
for file_name in os.listdir(data_dir):

    # get the .tif files
    if '.tif' in file_name:
        filename=file_name.replace('.tif', '')
        print('Working on map:', file_name)
        file_path=os.path.join(data_dir, file_name)
        test_json=file_path.replace('.tif', '.json')
        
        # read the legend annotation file
        with open(test_json) as f:
            data = json.load(f)

        # load image into an array
        im=cv2.imread(file_path)
        im=cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
        plt.imshow(im)
        plt.show()

        for shape in data['shapes']:

            # read labels and bounding box coordinates
            label = shape['label']
            points = shape['points']
            xy_min, xy_max = points
            x_min, y_min = xy_min
            x_max, y_max = xy_max
            
            template = im[int(y_min):int(y_max), int(x_min):int(x_max)]
            h, w = template.shape[0], template.shape[1]
            print('using the following legend feature for matching...:')
            plt.imshow(template)
            plt.show()
            
            print('detecting for label:', label)
            typ=label.split('_')[-1]
            print('type:', typ)
            
            
            ## To match point shapes
            if typ=='pt':
                
                # find all the template matches in the basemap
                res = cv2.matchTemplate(im, template,cv2.TM_CCOEFF_NORMED)
                threshold = 0.55
                loc = np.where( res >= threshold)
                
                # use the bounding boxes to create prediction binary raster
                pred_binary_raster=np.zeros((im.shape[0], im.shape[1]))
                for pt in zip(*loc[::-1]):
                    print('match found:')
                    pred_binary_raster[int(pt[1]+float(h)/2), pt[0] + int(float(w)/2)]=1
                    plt.imshow(im[pt[1]:pt[1] + h, pt[0]:pt[0] + w])
                    plt.show()

            
            ## To match lines and polygons
            else:
                
                if typ=='line':
                    # do edge detection
                    print('detecting lines in the legend feature...')
                    gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
                    edges = cv2.Canny(gray, threshold1=30, threshold2=100)
                    plt.imshow(edges)
                    plt.show()
                    central_pixel=tuple(np.argwhere(edges==255)[0])
                    sought = template[central_pixel].tolist()
                else: # type=='poly'
                    # take the median of the colors to find the predominant color
                    r=int(np.median(template[:,:,0]))
                    g=int(np.median(template[:,:,1]))
                    b=int(np.median(template[:,:,2]))
                    sought=[r, g, b]
                
                print('matching the color:', sought)
                
                lower = np.array(sought)-4
                lower[lower<0] = 0
                lower=tuple(lower.tolist())
                upper = np.array(sought)+4
                upper[upper>255] = 255
                upper=tuple(upper.tolist())
                pred_binary_raster = cv2.inRange(im, lower, upper)/255
            
            # print
            print('predicted binary raster:')
            print('shape:', pred_binary_raster.shape)
            print('unique value(s):', np.unique(pred_binary_raster))

            # plot the raster and save it
            plt.imshow(pred_binary_raster)
            plt.show()
            
            # save the raster into a .tif file
            out_file_path=os.path.join('results', filename+'_'+label+'.tif')
            pred_binary_raster=pred_binary_raster.astype('uint16')
            cv2.imwrite(out_file_path, pred_binary_raster)
            
            # convert the image to a binary raster .tif
            raster = rasterio.open(out_file_path)
            array = raster.read(1)
            with rasterio.open(
                out_file_path, "w",
                driver = "GTiff",
                transform = raster.transform,
                dtype = rasterio.uint8,
                count = 1,
                compress='lzw',
                crs = raster.crs,
                width = raster.width,
                height = raster.height) as dst:
                dst.write(array, indexes = 1)
# Out:
# Working on map: AZ_Arivaca_314329_1941_62500_geo_mosaic.tif
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33550 (0x830e) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33922 (0x8482) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34735 (0x87af) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34736 (0x87b0) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34737 (0x87b1) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 42112 (0xa480) encountered
# [ WARN:0@14.000] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 42113 (0xa481) encountered
# using the following legend feature for matching...:
# detecting for label: 3_pt
# type: pt
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# predicted binary raster:
# shape: (6225, 5088)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /Users/hunkim/Github/spatial_ml/.venv/lib/python3.10/site-packages/rasterio/__init__.py:366: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(
# detecting for label: 4_pt
# type: pt
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# predicted binary raster:
# shape: (6225, 5088)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: 5_pt
# type: pt
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# match found:
# predicted binary raster:
# shape: (6225, 5088)
# unique value(s): [0. 1.]
# Working on map: OG2.tif
# using the following legend feature for matching...:
# detecting for label: Qcr_poly
# type: poly
# matching the color: [250, 236, 199]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: PeShgr_poly
# type: poly
# matching the color: [207, 45, 33]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: Peqm_poly
# type: poly
# matching the color: [232, 132, 51]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: Kog_poly
# type: poly
# matching the color: [106, 120, 197]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: MJgr_poly
# type: poly
# matching the color: [241, 194, 229]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: MJNgd_poly
# type: poly
# matching the color: [246, 219, 201]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: Cpm_poly
# type: poly
# matching the color: [159, 109, 194]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: Fault_line
# type: line
# detecting lines in the legend feature...
# matching the color: [232, 232, 232]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]
# using the following legend feature for matching...:
# detecting for label: AccessRd_line
# type: line
# detecting lines in the legend feature...
# matching the color: [164, 167, 166]
# predicted binary raster:
# shape: (1718, 1276)
# unique value(s): [0. 1.]

# %%
# Test; load and plot the produced rasters
for file_name in os.listdir('results'):
    file_path = os.path.join('results', file_name)
    print('file_path:', file_path)
    im=cv2.imread(file_path)
    print(np.unique(im), im.shape)
    im[np.where(im==1)]=255
    plt.imshow(im)
    plt.show()
# Out:
# file_path: results/OG2_MJNgd_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@29.042] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/OG2_Fault_line.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@29.181] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/OG2_AccessRd_line.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@29.314] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/OG2_Qcr_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@29.448] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/OG2_PeShgr_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@29.578] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/AZ_Arivaca_314329_1941_62500_geo_mosaic_4_pt.tif
# [ WARN:0@29.713] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# [0 1] (6225, 5088, 3)
# file_path: results/OG2_Peqm_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@31.100] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/OG2_Kog_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@31.230] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/AZ_Arivaca_314329_1941_62500_geo_mosaic_3_pt.tif
# [ WARN:0@31.358] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# [0 1] (6225, 5088, 3)
# file_path: results/OG2_MJgr_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@32.752] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# file_path: results/AZ_Arivaca_314329_1941_62500_geo_mosaic_5_pt.tif
# [ WARN:0@32.886] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
# [0 1] (6225, 5088, 3)
# file_path: results/OG2_Cpm_poly.tif
# [0 1] (1718, 1276, 3)
# [ WARN:0@34.271] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34264 (0x85d8) encountered
