# %%
import argparse
import os
import sys
import logging
import pandas as pd
from pathlib import Path

# %%
prev = pd.read_csv("zoning_codes.csv")
updated = pd.read_csv("zoning_codes_all.csv")

# %%
# save into txt 
unique_codes = updated["zone_code"].unique()
with open("unique_codes.txt", "w") as f:
    for code in unique_codes:
        f.write(code + "\n")

# %%
sys.path.insert(0, os.path.dirname("../.."))

from utils.db_accessor import DBAccessor

# %%
#
